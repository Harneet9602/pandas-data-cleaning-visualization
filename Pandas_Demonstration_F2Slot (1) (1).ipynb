# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(10,80,size=(5,6)),\
index = ['R'+str(i+1) for i in range(5)],\
columns = ['C'+str(i+1) for i in range(6)])
df['Name'] = ['A','B','C','D','E']

# %%
df
# Out:
#     C1  C2  C3  C4  C5  C6 Name
# R1  72  17  48  14  58  16    A
# R2  27  66  52  20  65  48    B
# R3  56  24  74  18  59  14    C
# R4  22  24  17  58  10  32    D
# R5  65  37  45  65  37  21    E

# %%
for col,val in df.items():
    print(col,val)
    print(type(col),type(val))
# Out:
# C1 R1    72
# R2    27
# R3    56
# R4    22
# R5    65
# Name: C1, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C2 R1    17
# R2    66
# R3    24
# R4    24
# R5    37
# Name: C2, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C3 R1    48
# R2    52
# R3    74
# R4    17
# R5    45
# Name: C3, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C4 R1    14
# R2    20
# R3    18
# R4    58
# R5    65
# Name: C4, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C5 R1    58
# R2    65
# R3    59
# R4    10
# R5    37
# Name: C5, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C6 R1    16
# R2    48
# R3    14
# R4    32
# R5    21
# Name: C6, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# Name R1    A
# R2    B
# R3    C
# R4    D
# R5    E
# Name: Name, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>

# %%
for row,val in df.iterrows():
    print(row,val)
    print(type(row),type(val))
# Out:
# R1 C1      72
# C2      17
# C3      48
# C4      14
# C5      58
# C6      16
# Name     A
# Name: R1, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R2 C1      27
# C2      66
# C3      52
# C4      20
# C5      65
# C6      48
# Name     B
# Name: R2, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R3 C1      56
# C2      24
# C3      74
# C4      18
# C5      59
# C6      14
# Name     C
# Name: R3, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R4 C1      22
# C2      24
# C3      17
# C4      58
# C5      10
# C6      32
# Name     D
# Name: R4, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R5 C1      65
# C2      37
# C3      45
# C4      65
# C5      37
# C6      21
# Name     E
# Name: R5, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>

# %%
for t in df.itertuples():
    print(t)
    print(type(t))
# Out:
# Pandas(Index='R1', C1=72, C2=17, C3=48, C4=14, C5=58, C6=16, Name='A')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R2', C1=27, C2=66, C3=52, C4=20, C5=65, C6=48, Name='B')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R3', C1=56, C2=24, C3=74, C4=18, C5=59, C6=14, Name='C')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R4', C1=22, C2=24, C3=17, C4=58, C5=10, C6=32, Name='D')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R5', C1=65, C2=37, C3=45, C4=65, C5=37, C6=21, Name='E')
# <class 'pandas.core.frame.Pandas'>

# %%
df
# Out:
#     C1  C2  C3  C4  C5  C6 Name
# R1  72  17  48  14  58  16    A
# R2  27  66  52  20  65  48    B
# R3  56  24  74  18  59  14    C
# R4  22  24  17  58  10  32    D
# R5  65  37  45  65  37  21    E

# %%
df.index
# Out:
# Index(['R1', 'R2', 'R3', 'R4', 'R5'], dtype='object')

# %%
df.columns
# Out:
# Index(['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'Name'], dtype='object')

# %%
df.index = ['R1','R2','Row3','R4','Row5']

# %%
df
# Out:
#       C1  C2  C3  C4  C5  C6 Name
# R1    72  17  48  14  58  16    A
# R2    27  66  52  20  65  48    B
# Row3  56  24  74  18  59  14    C
# R4    22  24  17  58  10  32    D
# Row5  65  37  45  65  37  21    E

# %%
df.rename(index={'Row3':'R3','Row5':'R5'},columns={'C1':'Col1','C5':'Col5'},inplace=True)

# %%
df.rename(index={'R1':'ROW1'},columns={'Col1':'C1','Col5':'C5'})
# Out:
#       C1  C2  C3  C4  C5  C6 Name
# ROW1  72  17  48  14  58  16    A
# R2    27  66  52  20  65  48    B
# R3    56  24  74  18  59  14    C
# R4    22  24  17  58  10  32    D
# R5    65  37  45  65  37  21    E

# %%
df1 = df.copy()

# %%
df1
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    72  17  48  14    58  16    A
# R2    27  66  52  20    65  48    B
# R3    56  24  74  18    59  14    C
# R4    22  24  17  58    10  32    D
# R5    65  37  45  65    37  21    E

# %%
df1.iloc[[2,4,1],[1,3]] = np.nan

# %%
df1.iloc[[0,3],[0,2,4,5,6]]=np.nan

# %%
df1.iloc[2,6] = np.nan

# %%
df1
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN
# R2  27.0   NaN  52.0   NaN  65.0  48.0    B
# R3  56.0   NaN  74.0   NaN  59.0  14.0  NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN
# R5  65.0   NaN  45.0   NaN  37.0  21.0    E

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, R1 to R5
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    5 non-null      int32
#  1   C2      5 non-null      int32
#  2   C3      5 non-null      int32
#  3   C4      5 non-null      int32
#  4   Col5    5 non-null      int32
#  5   C6      5 non-null      int32
#  6   Name    5 non-null      object
# dtypes: int32(6), object(1)
# memory usage: 372.0+ bytes

# %%
df1.isna()
# Out:
#      Col1     C2     C3     C4   Col5     C6   Name
# R1   True  False   True  False   True   True   True
# R2  False   True  False   True  False  False  False
# R3  False   True  False   True  False  False   True
# R4   True  False   True  False   True   True   True
# R5  False   True  False   True  False  False  False

# %%
df1
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN
# R2  27.0   NaN  52.0   NaN  65.0  48.0    B
# R3  56.0   NaN  74.0   NaN  59.0  14.0  NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN
# R5  65.0   NaN  45.0   NaN  37.0  21.0    E

# %%
df1.dropna(how='all')
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN
# R2  27.0   NaN  52.0   NaN  65.0  48.0    B
# R3  56.0   NaN  74.0   NaN  59.0  14.0  NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN
# R5  65.0   NaN  45.0   NaN  37.0  21.0    E

# %%
df1.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [R1, R2, R3, R4, R5]

# %%
df1.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [Col1, C2, C3, C4, Col5, C6, Name]
# Index: []

# %%
df1.dropna(how='all')
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN
# R2  27.0   NaN  52.0   NaN  65.0  48.0    B
# R3  56.0   NaN  74.0   NaN  59.0  14.0  NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN
# R5  65.0   NaN  45.0   NaN  37.0  21.0    E

# %%
df1['Test'] = [np.nan]*len(df1.index)

# %%
df1
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name  Test
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN   NaN
# R2  27.0   NaN  52.0   NaN  65.0  48.0    B   NaN
# R3  56.0   NaN  74.0   NaN  59.0  14.0  NaN   NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN   NaN
# R5  65.0   NaN  45.0   NaN  37.0  21.0    E   NaN

# %%
df1.dropna(how='all',axis=1)
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN
# R2  27.0   NaN  52.0   NaN  65.0  48.0    B
# R3  56.0   NaN  74.0   NaN  59.0  14.0  NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN
# R5  65.0   NaN  45.0   NaN  37.0  21.0    E

# %%
df1['C2'].fillna(df['C2'].mean(),inplace=True)

# %%
df1
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name  Test
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN   NaN
# R2  27.0  33.6  52.0   NaN  65.0  48.0    B   NaN
# R3  56.0  33.6  74.0   NaN  59.0  14.0  NaN   NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN   NaN
# R5  65.0  33.6  45.0   NaN  37.0  21.0    E   NaN

# %%
df1.fillna(df)
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name  Test
# R1  72.0  17.0  48.0  14.0  58.0  16.0    A   NaN
# R2  27.0  33.6  52.0  20.0  65.0  48.0    B   NaN
# R3  56.0  33.6  74.0  18.0  59.0  14.0    C   NaN
# R4  22.0  24.0  17.0  58.0  10.0  32.0    D   NaN
# R5  65.0  33.6  45.0  65.0  37.0  21.0    E   NaN

# %%
df1
# Out:
#     Col1    C2    C3    C4  Col5    C6 Name  Test
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN   NaN
# R2  27.0  33.6  52.0   NaN  65.0  48.0    B   NaN
# R3  56.0  33.6  74.0   NaN  59.0  14.0  NaN   NaN
# R4   NaN  24.0   NaN  58.0   NaN   NaN  NaN   NaN
# R5  65.0  33.6  45.0   NaN  37.0  21.0    E   NaN

# %%
df1.fillna(method='ffill',limit=2)
# Out:
# C:\Users\harne\AppData\Local\Temp\ipykernel_9564\3521651076.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='ffill',limit=2)
#     Col1    C2    C3    C4  Col5    C6 Name  Test
# R1   NaN  17.0   NaN  14.0   NaN   NaN  NaN   NaN
# R2  27.0  33.6  52.0  14.0  65.0  48.0    B   NaN
# R3  56.0  33.6  74.0  14.0  59.0  14.0    B   NaN
# R4  56.0  24.0  74.0  58.0  59.0  14.0    B   NaN
# R5  65.0  33.6  45.0  58.0  37.0  21.0    E   NaN

# %%
df
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    72  17  48  14    58  16    A
# R2    27  66  52  20    65  48    B
# R3    56  24  74  18    59  14    C
# R4    22  24  17  58    10  32    D
# R5    65  37  45  65    37  21    E

# %%
df.to_csv('DF.txt',sep='\t')

# %%
df.to_excel('DF.xlsx',sheet_name='Data')

# %%
dfn = pd.read_csv('DF.txt',sep='\t',index_col=0,skiprows=0)
dfn
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    72  17  48  14    58  16    A
# R2    27  66  52  20    65  48    B
# R3    56  24  74  18    59  14    C
# R4    22  24  17  58    10  32    D
# R5    65  37  45  65    37  21    E

# %%
dfe = pd.read_excel('DF.xlsx',index_col=0)
dfe
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    72  17  48  14    58  16    A
# R2    27  66  52  20    65  48    B
# R3    56  24  74  18    59  14    C
# R4    22  24  17  58    10  32    D
# R5    65  37  45  65    37  21    E

# %%
Data = pd.read_excel('WQ.xlsx')
x1=pd.ExcelFile('WQ.xlsx')
names=x1.sheet_names
names[2]
# Out:
# 'Dec 04'

# %%
Dec04=pd.read_excel('WQ.xlsx',sheet_name=names[2])
Dec04
# Out:
#     St. No  Depth   S.D   W.T  Salinity  Turbidity     DO    pH     TSM  \
# 0        1   0.50  0.50  27.5     15.36       3.50  11.28  9.18   18.00
# 1        2   2.35  0.75  25.5     15.48       8.89   9.34  8.65   24.00
# 2        3   2.65  1.00  25.1     15.87       8.34   7.97  8.44   17.95
# 3        4   2.25  2.00  25.9     16.64       1.59   7.97  8.76    9.70
# 4        5   1.75  1.75  25.8     14.97       0.81   9.59  8.67    6.00
# 5        6   2.50  0.75  25.4     14.59       5.09   8.06  8.55   16.40
# 6        7   2.75  1.50  25.1     13.82       4.98   7.25  8.46   14.25
# 7        8   0.25  0.25  25.8     13.44       0.15   9.59  8.80    9.12
# 8        9   0.25  0.25  25.6     14.08       1.77   7.25  8.64    8.50
# 9       10   2.75  1.25  25.3     13.44       4.24   7.25  8.44   15.60
# 10      11   0.50  0.50  24.4     13.31       0.47   8.86  8.47    8.50
# 11      12   1.75  0.75  25.0     12.16      10.02   7.70  8.32   24.00
# ...

# %%
Dec04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   St. No     36 non-null     int64
#  1   Depth      36 non-null     float64
#  2   S.D        36 non-null     float64
#  3   W.T        36 non-null     float64
#  4   Salinity   36 non-null     float64
#  5   Turbidity  36 non-null     float64
#  6   DO         36 non-null     float64
#  7   pH         36 non-null     float64
#  8   TSM        36 non-null     float64
#  9   NH4-N      36 non-null     float64
#  10  NO2-N      36 non-null     float64
#  11  NO3-N      35 non-null     float64
#  12  PO4-P      36 non-null     float64
#  13  SiO2-Si    36 non-null     float64
#  14  TN         36 non-null     float64
#  15  TP         36 non-null     float64
# dtypes: float64(15), int64(1)
# memory usage: 4.6 KB

# %%
Dec04.describe()
# Out:
#           St. No      Depth        S.D       W.T   Salinity   Turbidity  \
# count  36.000000  36.000000  36.000000  36.00000  36.000000   36.000000
# mean   18.500000   1.568889   0.747778  26.37500   9.202778   24.712222
# std    10.535654   0.748037   0.603306   1.25274   6.215895   37.361489
# min     1.000000   0.250000   0.000000  24.40000   0.380000    0.150000
# 25%     9.750000   1.000000   0.200000  25.40000   2.617500    3.152500
# 50%    18.500000   1.500000   0.750000  26.15000  11.385000    5.960000
# 75%    27.250000   2.062500   1.062500  26.95000  13.535000   23.200000
# max    36.000000   3.000000   2.000000  29.50000  24.320000  141.000000
#
#               DO         pH         TSM      NH4-N      NO2-N      NO3-N  \
# count  36.000000  36.000000   36.000000  36.000000  36.000000  35.000000
# mean    8.226944   8.521111   26.137778   4.064028   0.149749   0.774082
# std     1.403660   0.444437   28.653874   1.701949   0.133673   0.483857
# ...

# %%
Dec04.plot(subplots=True,figsize=(8,30))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
Dec04.columns
# Out:
# Index(['St. No', 'Depth', 'S.D', 'W.T', 'Salinity', 'Turbidity', 'DO', 'pH',
#        'TSM', 'NH4-N', 'NO2-N', 'NO3-N', 'PO4-P', 'SiO2-Si', 'TN', 'TP'],
#       dtype='object')

# %%
Dec04.plot(x='St. No',y='Depth',kind='scatter')
# Out:
# <Axes: xlabel='St. No', ylabel='Depth'>

# %%
Dec04['Depth'].plot.bar(figsize=(8,3),xlabel='St. No',ylabel='Depth',\
                           title='Plot of Depth as Bar Chart')
# Out:
# <Axes: title={'center': 'Plot of Depth as Bar Chart'}, xlabel='St. No', ylabel='Depth'>

# %%
Dec04[['Depth','DO']].plot.pie(subplots=True,legend=False)
# Out:
# array([<Axes: ylabel='Depth'>, <Axes: ylabel='DO'>], dtype=object)

# %%
[method_name for method_name in dir(Dec04.plot) \
 if not method_name.startswith("_")]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
Dec04.plot(kind='kde',figsize=(8,30),subplots=True)
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>], dtype=object)

# %%
Dec04[['Depth','DO']].plot(kind='area',legend=True)
plt.show()

# %%
Dec04.plot(kind='line',legend=True)
plt.legend(bbox_to_anchor=(1, 0),loc='lower left')
plt.show()

# %%
exl = pd.ExcelFile('WQ.xlsx')

# %%
exl.sheet_names
# Out:
# ['May 04', 'Sep 04', 'Dec 04', 'Mar 05']

# %%
exl = pd.ExcelFile('WQ.xlsx')
Data = pd.DataFrame()
for sheet in exl.sheet_names:
    temp = pd.read_excel('WQ.xlsx',sheet_name = sheet)
    Data = pd.concat([Data,temp])

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   St. No     144 non-null    int64
#  1   Depth      143 non-null    object
#  2   S.D        142 non-null    float64
#  3   W.T        143 non-null    float64
#  4   Salinity   143 non-null    float64
#  5   Turbidity  141 non-null    float64
#  6   DO         143 non-null    float64
#  7   pH         143 non-null    float64
#  8   TSM        141 non-null    float64
#  9   NH4-N      143 non-null    float64
#  10  NO2-N      143 non-null    float64
#  11  NO3-N      142 non-null    float64
#  12  PO4-P      143 non-null    float64
#  13  SiO2-Si    143 non-null    float64
#  14  TN         139 non-null    float64
#  15  TP         129 non-null    float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 19.1+ KB

# %%
Data.loc[1]
# Out:
#    St. No Depth   S.D   W.T  Salinity  Turbidity    DO    pH    TSM    NH4-N  \
# 1       2  2.25  0.50  30.0     10.40      16.00  6.90  8.27   23.2  9.90000
# 1       2  2.25  0.50  31.5     19.50      23.00  7.30  8.38   16.2  1.98000
# 1       2  2.35  0.75  25.5     15.48       8.89  9.34  8.65   24.0  3.28020
# 1       2  1.85  0.00  30.5     18.40     151.00  6.45  8.21  210.0  0.12711
#
#      NO2-N    NO3-N    PO4-P   SiO2-Si        TN        TP
# 1  0.39000  1.04000  4.50000   8.00000  19.10000  11.60000
# 1  0.04840  1.17220  0.13860  12.95626   6.13815   1.10292
# 1  0.06786  0.94707  0.16864  15.89184  24.79776   0.30783
# 1  0.10460  0.65428  0.10204  47.43882  28.70280   0.51636

# %%
WQData = pd.read_excel(r'https://bsrvp.github.io/PythonClass/WQ.xlsx')

# %%
WQData['Depth'].plot.bar()
# Out:
# <Axes: >

# %%
WQData.plot(kind='scatter', x='Depth', y='DO')
# Out:
# <Axes: xlabel='Depth', ylabel='DO'>

# %%
WQData['DO'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
WQData.plot(x='St. No', y='DO', ylabel='DO')
# Out:
# <Axes: xlabel='St. No', ylabel='DO'>

# %%
WQData.plot.area(figsize=(8,10),subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >], dtype=object)

# %%
axs=WQData.plot(figsize=(6,10),subplots=True)

# %%
WQData.plot.bar(subplots=True)
# Out:
# array([<Axes: title={'center': 'St. No'}>,
#        <Axes: title={'center': 'Depth'}>, <Axes: title={'center': 'S.D'}>,
#        <Axes: title={'center': 'W.T'}>,
#        <Axes: title={'center': 'Turbidity'}>,
#        <Axes: title={'center': 'DO'}>, <Axes: title={'center': 'pH'}>,
#        <Axes: title={'center': 'TSM'}>], dtype=object)

# %%
WQData.plot.box(subplots=True)
# Out:
# St. No          Axes(0.125,0.11;0.0824468x0.77)
# Depth        Axes(0.223936,0.11;0.0824468x0.77)
# S.D          Axes(0.322872,0.11;0.0824468x0.77)
# W.T          Axes(0.421809,0.11;0.0824468x0.77)
# Turbidity    Axes(0.520745,0.11;0.0824468x0.77)
# DO           Axes(0.619681,0.11;0.0824468x0.77)
# pH           Axes(0.718617,0.11;0.0824468x0.77)
# TSM          Axes(0.817553,0.11;0.0824468x0.77)
# dtype: object
